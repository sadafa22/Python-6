# %%
#Question 1

#(i) Data cleaning and finding missing values

# %%
#importing libraries
import pandas as pd
import seaborn as sns

# %%
#Read csv file into pandas dataframe
df = pd.read_csv('Mamani09_Table_DR2_V2.csv')
df
# Out:
#               Arc     Sample    Location Geologycal_age    Domain  \
# 0     Frontal arc  SAR-00-08   Sara Sara     Quaternary   Paracas
# 1     Frontal arc  SAR-00-07   Sara Sara     Quaternary   Paracas
# 2     Frontal arc  SAR-00-13   Sara Sara     Quaternary   Paracas
# 3     Frontal arc  SAR-00-06   Sara Sara     Quaternary   Paracas
# 4     Frontal arc  SAR-00-10   Sara Sara     Quaternary   Paracas
# ...           ...        ...         ...            ...       ...
# 1783  Proterozoic     Uya-06  C� Uyarani    Proterozoic  Arequipa
# 1784  Proterozoic     Uya-07  C� Uyarani    Proterozoic  Arequipa
# 1785  Proterozoic      JK 11  C� Uyarani    Proterozoic  Arequipa
# 1786          NaN        NaN         NaN            NaN       NaN
# 1787          NaN        NaN         NaN            NaN       NaN
#
#        Sample_type    Rock_type Geochemistry Reference  Country  Age  (Ma)  \
# 0             lava     andesite    Mamani et al., 2008     Peru       1.62
# ...

# %%
#Deleting empty columns to make the columns uniform
del df["Unnamed: 28"]
del df["Unnamed: 44"]
del df["Unnamed: 81"]
del df["Unnamed: 87"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1788 entries, 0 to 1787
# Data columns (total 97 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arc                     1786 non-null   object
#  1   Sample                  1786 non-null   object
#  2   Location                1778 non-null   object
#  3   Geologycal_age          1786 non-null   object
#  4   Domain                  1786 non-null   object
#  5   Sample_type             1786 non-null   object
#  6   Rock_type               1783 non-null   object
#  7   Geochemistry Reference  1786 non-null   object
#  8   Country                 1786 non-null   object
#  9   Age  (Ma)               282 non-null    float64
#  10  error (Ma)              255 non-null    object
#  11  Age Reference           282 non-null    object
#  12  Longitude (X)           1786 non-null   float64
#  13  Latitude (Y)            1786 non-null   float64
# ...

# %%
#Replacing all empty values with previous values so that there are no missing values
df.fillna(method='pad', inplace=True)

# %%
#Replacing all empty values with 0 for specific columns 
df.fillna(0, inplace=True)

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1788 entries, 0 to 1787
# Data columns (total 97 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Arc                     1788 non-null   object
#  1   Sample                  1788 non-null   object
#  2   Location                1788 non-null   object
#  3   Geologycal_age          1788 non-null   object
#  4   Domain                  1788 non-null   object
#  5   Sample_type             1788 non-null   object
#  6   Rock_type               1788 non-null   object
#  7   Geochemistry Reference  1788 non-null   object
#  8   Country                 1788 non-null   object
#  9   Age  (Ma)               1788 non-null   float64
#  10  error (Ma)              1788 non-null   object
#  11  Age Reference           1788 non-null   object
#  12  Longitude (X)           1788 non-null   float64
#  13  Latitude (Y)            1788 non-null   float64
# ...

# %%
#Plotting a seasborn countplot for the output which is sample_type
sns.countplot(data=df, x='Sample_type')
# Out:
# <AxesSubplot:xlabel='Sample_type', ylabel='count'>

# %%
#Visual represention using the seaborn heatmap of the data
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Finding empty columns
missing_values = df.columns[df.isnull().any()]
for i in missing_values:
  if df[i].isnull().sum()*100.0/df.shape[0] < 100:
    print(i, df[i].isnull().sum())

# %%
#Checking if any missing values exist in any columns
df.isnull().sum()
# Out:
# Arc               0
# Sample            0
# Location          0
# Geologycal_age    0
# Domain            0
#                  ..
# 206Pb_error       0
# 207_204Pb         0
# 207Pb_error       0
# 208Pb_204Pb       0
# 208Pb_error       0
# Length: 97, dtype: int64

# %%
# Qestion 1
(ii)Converting non numeric data to numeric

# %%
df['Sample_type'].unique()
# Out:
# array(['lava', 'ignimbrite', 'ash', 'intrusion', 'metamorphic',
#        'metamorphic ', 'dike'], dtype=object)

# %%
#Assigning numbers to each column in sample_type
df['Sample_type'] = df['Sample_type'].replace('metamorphic ','metamorphic')
df['Sample_type'] = df['Sample_type'].map({ 'lava':1,
                                            'ignimbrite':2,
                                            'ash':3,
                                            'intrusion':4,
                                            'metamorphic':5,                                                                                                                       
                                            'dike':6
                                            }
                                         )
df['Sample_type'] = df['Sample_type'].fillna(0)
print(df['Sample_type'].unique())
# Out:
# [1 2 3 4 5 6]

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Sample_type'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Sample_type'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [4 4 4 ... 6 6 6]
# ['lava' 'lava' 'lava' ... 'metamorphic ' 'metamorphic ' 'metamorphic ']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Country'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Country'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [4 4 4 ... 2 2 2]
# ['Peru' 'Peru' 'Peru' ... 'Bolivia' 'Bolivia' 'Bolivia']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Domain'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Domain'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [3 3 3 ... 1 1 1]
# ['Paracas' 'Paracas' 'Paracas' ... 'Arequipa' 'Arequipa' 'Arequipa']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Geochemistry Reference'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Geochemistry Reference'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [38 38 38 ... 59 59 59]
# ['Mamani et al., 2008' 'Mamani et al., 2008' 'Mamani et al., 2008' ...
#  'W�rner et al., 2000' 'W�rner et al., 2000' 'W�rner et al., 2000']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Arc'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Arc'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [ 2  2  2 ... 26 26 26]
# ['Frontal arc' 'Frontal arc' 'Frontal arc' ... 'Proterozoic' 'Proterozoic'
#  'Proterozoic']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Geologycal_age'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Geologycal_age'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [20 20 20 ... 19 19 19]
# ['Quaternary' 'Quaternary' 'Quaternary' ... 'Proterozoic' 'Proterozoic'
#  'Proterozoic']

# %%
#Using label encoder to convert all non numeric to numeric
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
enc.fit(df['Rock_type'].values.ravel())
list(enc.classes_)
Sample_type_encoded = enc.transform(df['Rock_type'].values.ravel())
#df[['Sample_type_encoded']] = Sample_type_encoded
print(Sample_type_encoded)
print(enc.inverse_transform(Sample_type_encoded))
# Out:
# [ 3  3  3 ... 13 13 13]
# ['andesite' 'andesite' 'andesite' ... 'granulite' 'granulite' 'granulite']

# %%
enc = OneHotEncoder(handle_unknown='ignore')
X = [['ash', 1], ['lava', 3], ['ignimite', 2]]
enc.fit(X)
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
enc.transform([['lava', 1], ['ash', 4]]).toarray()
# Out:
# array([[0., 0., 1., 1., 0., 0.],
#        [1., 0., 0., 0., 0., 0.]])

# %%
enc.get_feature_names(['Sample_type','lava'])
# Out:
# array(['Sample_type_ash', 'Sample_type_ignimite', 'Sample_type_lava',
#        'lava_1', 'lava_2', 'lava_3'], dtype=object)

# %%
#Question 2 (ALGORIHMS AND MODELS)

# %%
from sklearn.model_selection import train_test_split
X = df.iloc[:,1:96].values
y = df.iloc[:,0].values
Xtrain, Xtest, ytrain, ytest=train_test_split(X, y, test_size = 10)

# %%
print(X)
# Out:
# [['SAR-00-08' 'Sara Sara' 'Quaternary' ... 15.669 0.001 38.88]
#  ['SAR-00-07' 'Sara Sara' 'Quaternary' ... 15.669 0.001 38.88]
#  ['SAR-00-13' 'Sara Sara' 'Quaternary' ... 15.686 0.001 38.897]
#  ...
#  ['JK 11' 'C� Uyarani' 'Proterozoic' ... 15.644 0.001 38.469]
#  ['JK 11' 'C� Uyarani' 'Proterozoic' ... 15.644 0.001 38.469]
#  ['JK 11' 'C� Uyarani' 'Proterozoic' ... 15.644 0.001 38.469]]

# %%
df.head()
# Out:
#            Arc     Sample   Location Geologycal_age   Domain  Sample_type  \
# 0  Frontal arc  SAR-00-08  Sara Sara     Quaternary  Paracas            1
# 1  Frontal arc  SAR-00-07  Sara Sara     Quaternary  Paracas            1
# 2  Frontal arc  SAR-00-13  Sara Sara     Quaternary  Paracas            1
# 3  Frontal arc  SAR-00-06  Sara Sara     Quaternary  Paracas            2
# 4  Frontal arc  SAR-00-10  Sara Sara     Quaternary  Paracas            2
#
#   Rock_type Geochemistry Reference Country  Age  (Ma)  ... 143_144Nd  \
# 0  andesite    Mamani et al., 2008    Peru       1.62  ...   0.51247
# 1  andesite    Mamani et al., 2008    Peru       1.62  ...   0.51247
# 2  andesite    Mamani et al., 2008    Peru       1.62  ...   0.51246
# 3  rhyolite    Mamani et al., 2008    Peru       1.62  ...   0.51246
# 4  rhyolite    Mamani et al., 2008    Peru       1.62  ...   0.51246
#
#   143_144Nd_error  eNd  TDM ages  206_204Pb  206Pb_error  207_204Pb  \
# ...

# %%
del df["Geologycal_age"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1788 entries, 0 to 1787
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Location         1788 non-null   object
#  1   Domain           1788 non-null   object
#  2   Sample_type      1788 non-null   int64
#  3   Rock_type        1788 non-null   object
#  4   Country          1788 non-null   object
#  5   Age  (Ma)        1788 non-null   float64
#  6   Longitude (X)    1788 non-null   float64
#  7   Latitude (Y)     1788 non-null   float64
#  8   SiO2             1788 non-null   float64
#  9   TiO2             1788 non-null   float64
#  10  Al2O3            1788 non-null   float64
#  11  Fe2O3            1788 non-null   float64
#  12  MnO              1788 non-null   float64
#  13  MgO              1788 non-null   float64
#  14  CaO              1788 non-null   float64
#  15  Na2O             1788 non-null   float64
# ...

# %%
df.head()
# Out:
#     Location   Domain  Sample_type Rock_type Country  Age  (Ma)  \
# 0  Sara Sara  Paracas            1  andesite    Peru       1.62
# 1  Sara Sara  Paracas            1  andesite    Peru       1.62
# 2  Sara Sara  Paracas            1  andesite    Peru       1.62
# 3  Sara Sara  Paracas            2  rhyolite    Peru       1.62
# 4  Sara Sara  Paracas            2  rhyolite    Peru       1.62
#
#    Longitude (X)  Latitude (Y)  SiO2  TiO2  ...  143_144Nd  143_144Nd_error  \
# 0        -73.336       -15.136  58.9  1.13  ...    0.51247          0.00001
# 1        -73.347       -15.200  62.9  0.83  ...    0.51247          0.00001
# 2        -73.419       -15.252  60.6  1.02  ...    0.51246          0.00000
# 3        -73.366       -15.271  65.0  0.41  ...    0.51246          0.00000
# 4        -73.548       -15.314  68.6  0.36  ...    0.51246          0.00000
#
#    eNd  TDM ages  206_204Pb  206Pb_error  207_204Pb  207Pb_error  208Pb_204Pb  \
# ...

# %%
#apply KNN model
from sklearn.neighbors import KNeighborsClassifier
classifier= KNeighborsClassifier(n_neighbors=5)
classifier.fit(Xtrain, ytrain)
y_predict_train=classifier.predict(Xtrain)
y_predict_test=classifier.predict(Xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-dc9a27800062> in <module>
#       2 from sklearn.neighbors import KNeighborsClassifier
#       3 classifier= KNeighborsClassifier(n_neighbors=5)
# ----> 4 classifier.fit(Xtrain, ytrain)
#       5 y_predict_train=classifier.predict(Xtrain)
#       6 y_predict_test=classifier.predict(Xtest)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177             The fitted k-nearest neighbors classifier.
#     178         """
# --> 179         return self._fit(X, y)
#     180
#     181     def predict(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     361         if self._get_tags()["requires_y"]:
#     362             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# ...

# %%
#Extracting Independent and dependent Variable  
x= df.iloc[:, [1,50]].values  
y= df.iloc[:, 5].values  
  
# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)  
  
#featuring Scaling  
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-732dabb6ab87> in <module>
#      10 from sklearn.preprocessing import StandardScaler
#      11 st_x= StandardScaler()
# ---> 12 x_train= st_x.fit_transform(x_train)
#      13 x_test= st_x.transform(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
# ...

# %%
#Using 10 fold evaluation

# %%
from sklearn import datasets
iris = datasets.load_iris()
X=df.iloc[1:50]
y=df.iloc[1:50]
#create KNN model
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)

# %%
from sklearn.model_selection import cross_val_score
scores=cross_val_score(knn,X,y, cv=13,scoring="accuracy")
print(scores)
print(scores.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-37147ace0b90> in <module>
#       1 from sklearn.model_selection import cross_val_score
# ----> 2 scores=cross_val_score(knn,X,y, cv=13,scoring="accuracy")
#       3 print(scores)
#       4 print(scores.mean())
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     438     scorer = check_scoring(estimator, scoring=scoring)
#     439
# ...

# %% [markdown]
# ### import numpy as np
# k_range=np.arange(1,31)
# weight_options=['Sample_type','Rock_type']
# param_grid=dict(n_neighbors =k_range, weights=weight_options)
# print(param_grid)

# %%
from sklearn.model_selection import GridSearchCV
grid=GridSearchCV(knn,param_grid,cv=10,scoring='accuracy',return_train_score=False)
grid.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-96c5cccd2065> in <module>
#       1 from sklearn.model_selection import GridSearchCV
#       2 grid=GridSearchCV(knn,param_grid,cv=10,scoring='accuracy',return_train_score=False)
# ----> 3 grid.fit(X,y)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     760         fit_params = _check_fit_params(X, fit_params)
#     761
# --> 762         cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV

clf = RandomizedSearchCV(knn, param_grid, n_iter=100, cv=5, random_state=1)
model = clf.fit(X,y)

print(" Results from Random Search " )
print( model.best_estimator_)
print("\n The best score across ALL searched params:\n", model.best_score_)
print("\n The best parameters across ALL searched params:\n", model.best_params_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-82ccb7041da5> in <module>
#       2
#       3 clf = RandomizedSearchCV(knn, param_grid, n_iter=100, cv=5, random_state=1)
# ----> 4 model = clf.fit(X,y)
#       5
#       6 print(" Results from Random Search " )
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     760         fit_params = _check_fit_params(X, fit_params)
#     761
# --> 762         cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
# ...

# %%
#Question-3 incomplete
